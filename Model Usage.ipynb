# %% [markdown]
# # using model

# %%
from joblib import dump, load
import numpy as np
model=load('Dragon.joblib')
input= np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.24686758, -1.31238772,  12.61111401, -1.0016859 , -100.5778192 ,
       -0.97491834,  33.41164221, -0.86091034]])
model.predict(input)
# Out:
# array([24.929])
